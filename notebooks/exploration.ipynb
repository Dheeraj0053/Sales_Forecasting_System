# %% [markdown]
# # Time Series Exploration\n\nUse this notebook for exploratory analysis before training production models.

# %%
import pandas as pd\n\ndf = pd.read_excel('../data/raw.xlsx')\ndf.head()
